# %% [markdown]
# # Assignment 2b
# ## Student name: NAN XIAO, Student ID: 30280443

# %% [markdown]
# # Task 2 Streaming application using Spark Structured Streaming

# %% [markdown]
# <a class="anchor" id="lab-task-1"></a>
# <div style="background:rgba(0,109,174,0.2);padding:10px;border-radius:4px"><strong style="color:#FF5555">DESCRIPTION</strong>
# <br>In this task, I will implement Spark Structured Streaming to consume the data from Kafka server and do the prediction.
# </div>

# %% [markdown]
# ## 2.1  Create SparkSession

# %%
import os
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-streaming-kafka-0-10_2.12:3.0.0,org.apache.spark:spark-sql-kafka-0-10_2.12:3.0.0 pyspark-shell'
from pyspark import SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode, udf
from pyspark.sql.functions import split
from pyspark.sql.functions import col, decode, expr
from pyspark.sql import functions as F
from pyspark.sql.types import *
import json
import datetime as dt

# local[*]: run Spark in local mode with as many working processors as logical cores on your machine
master = "local[*]"
# Config app name which will be shown on the Spark cluster UI page
app_name = "Melbourne pedestrian traffic"

# Setup configuration parameters for Spark
spark_conf = SparkConf().setMaster(master).setAppName(app_name)

# Import SparkContext and SparkSession classes
from pyspark import SparkContext # Spark
from pyspark.sql import SparkSession, Row # Spark SQL

# Configure timezone
# CODE REFERENCE -- https://stackoverflow.com/questions/49644232/apache-spark-how-to-set-timezone-to-utc-currently-defaulted-to-zulu
spark = SparkSession.builder.config(conf=spark_conf).config('spark.sql.session.timeZone', 'UTC').getOrCreate()

sc = spark.sparkContext
sc.setLogLevel('ERROR')

# %% [markdown]
# ## 2.2 Load the sensor data

# %%
# Define the schema
schema_s = StructType([
   StructField("sensor_id", IntegerType(), True),
   StructField("sensor_description", StringType(), True),
   StructField("sensor_name", StringType(), True),
   StructField("installation_date",  DateType(), True),
   StructField("status", StringType(), True),
   StructField("note", StringType(), True),
   StructField("direction_1", StringType(), True),
   StructField("direction_2", StringType(), True),
   StructField("latitude", FloatType(), True),
   StructField("longitude", FloatType(), True),
   StructField("location", StringType(), True)])

# %%
# Load data
df_sensor = spark.read.csv("Pedestrian_Counting_System_-_Sensor_Locations.csv",\
                           header=True, sep=",", schema=schema_s, dateFormat = "yyyy/MM/dd")

# %%
df_sensor.printSchema()
# Out:
# root
#  |-- sensor_id: integer (nullable = true)
#  |-- sensor_description: string (nullable = true)
#  |-- sensor_name: string (nullable = true)
#  |-- installation_date: date (nullable = true)
#  |-- status: string (nullable = true)
#  |-- note: string (nullable = true)
#  |-- direction_1: string (nullable = true)
#  |-- direction_2: string (nullable = true)
#  |-- latitude: float (nullable = true)
#  |-- longitude: float (nullable = true)
#  |-- location: string (nullable = true)

# %% [markdown]
# ## 2.3 Ingest the streaming data

# %%
# Read Stream from the Kafka Topic

# Define the topic that will retrive from kafka server
topic = "sensor_data"
counts_df_read = spark \
  .readStream \
  .format("kafka") \
  .option("kafka.bootstrap.servers", "127.0.0.1:9092") \
  .option("subscribe", topic) \
  .load()

# %% [markdown]
# ## 2.4 Persist the raw streaming data in parquet format

# %%
# Write the streaming data to parquet file
write_parquet = counts_df_read.writeStream\
    .format("parquet")\
    .outputMode("append")\
    .option("path", "counts.parquet")\
    .option("checkpointLocation","parquet/counts_df/checkpoint")\
    .start()
# Need to run this command for a few seconds then stop, otherwise the parquet will be empty

# %%
write_parquet.stop()

# %%
# Test if the writing is successful
read_parquet_df = spark.read.parquet("counts.parquet")
read_parquet_df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %% [markdown]
# ## 2.5 Transform data formats

# %% [markdown]
# <a class="anchor" id="lab-task-1"></a>
# <div style="background:rgba(0,109,174,0.2);padding:10px;border-radius:4px"><strong style="color:#FF5555">DESCRIPTION</strong>
# <br>In this task, First is to get the column we need from streaming data, which are value and timestamp.
# <br>Value column consists the data and the timestamp is the event time that kafka received the data from producer. The timestamp will be used define the time-based window.
# <br>After get the column I need, I defined the schema to match the data type of the streaming, so that I can use the from_json function to parse the value.
# <br>Then is to transfer the data type according to the meta data file.
# </div>

# %%
# Get the value column and timestamp column and transfer them into string format
counts_df_read = counts_df_read.selectExpr("CAST(value AS STRING)","CAST(timestamp AS STRING)")

# %%
counts_df_read.printSchema()
# Out:
# root
#  |-- value: string (nullable = true)
#  |-- timestamp: string (nullable = true)

# %%
#Define the schema for the structured datastream received
schema = StructType([
   StructField("ID", StringType(), True),
   StructField("Date_Time", StringType(), True),
   StructField('Year', StringType(), True),
   StructField("Month", StringType(), True),
   StructField("Mdate", StringType(), True),
   StructField("Day", StringType(), True),
   StructField("Time", StringType(), True),
   StructField("Sensor_ID", StringType(), True),
   StructField("Sensor_Name", StringType(), True),
   StructField("Hourly_Counts", StringType(), True)])

listSchema = ArrayType(schema)

# %%
counts_df = counts_df_read\
       .select(F.from_json(F.col("value").cast("string"),listSchema).alias('parsed_value')\
               ,F.col("timestamp").cast("string"))\
       .select(explode(F.col("parsed_value")).alias("unnested_values"),"timestamp")\
       .select(F.col("unnested_values.*"), "timestamp")\
       .withColumn("ID",F.col("ID").cast(IntegerType()))\
       .withColumn("Year",F.col("Year").cast(IntegerType()))\
       .withColumn("Mdate", F.col("Mdate").cast(IntegerType()))\
       .withColumn("Time", F.col("Time").cast(IntegerType()))\
       .withColumn("Sensor_ID", F.col("Sensor_ID").cast(IntegerType()))\
       .withColumn("Hourly_Counts", F.col("Hourly_Counts").cast(IntegerType()))\
       .withColumn("Date_Time",F.to_timestamp("Date_Time",'MM/dd/yyyy hh:mm:ss a'))\
       .withColumn("timestamp",F.to_timestamp("timestamp",'yyyy-MM-dd hh:mm:ss.SSS'))

# %%
# Print schema to test if the data is transfered successful
counts_df.printSchema()
# Out:
# root
#  |-- ID: integer (nullable = true)
#  |-- Date_Time: timestamp (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Month: string (nullable = true)
#  |-- Mdate: integer (nullable = true)
#  |-- Day: string (nullable = true)
#  |-- Time: integer (nullable = true)
#  |-- Sensor_ID: integer (nullable = true)
#  |-- Sensor_Name: string (nullable = true)
#  |-- Hourly_Counts: integer (nullable = true)
#  |-- timestamp: timestamp (nullable = true)

# %%
# Query to test if the data is transfered successful
query = counts_df\
    .writeStream\
    .outputMode("append")\
    .format("memory")\
    .queryName("counts_df")\
    .trigger(processingTime="2 seconds")\
    .start()

# %%
counts_df_final = spark.sql("select * from counts_df").toPandas()

# %%
counts_df_final.head(10)
# Out:
#         ID           Date_Time  Year     Month  Mdate     Day  Time  \
# 0  3444255 2020-12-07 01:00:00  2020  December      7  Monday     1
# 1  3444537 2020-12-07 05:00:00  2020  December      7  Monday     5
# 2  3444155 2020-12-07 00:00:00  2020  December      7  Monday     0
# 3  3444156 2020-12-07 00:00:00  2020  December      7  Monday     0
# 4  3444157 2020-12-07 00:00:00  2020  December      7  Monday     0
# 5  3444158 2020-12-07 00:00:00  2020  December      7  Monday     0
# 6  3444159 2020-12-07 00:00:00  2020  December      7  Monday     0
# 7  3444160 2020-12-07 00:00:00  2020  December      7  Monday     0
# 8  3444162 2020-12-07 00:00:00  2020  December      7  Monday     0
# 9  3444163 2020-12-07 00:00:00  2020  December      7  Monday     0
#
#    Sensor_ID                 Sensor_Name  Hourly_Counts  \
# 0         35                   Southbank             47
# 1         71              Westwood Place             11
# 2          4            Town Hall (West)             98
# 3         17       Collins Place (South)             14
# 4         18       Collins Place (North)              8
# 5         53          Collins St (North)             16
# 6          2  Bourke Street Mall (South)             25
# 7          1  Bourke Street Mall (North)             65
# 8          9      Southern Cross Station             10
# 9         10              Victoria Point              3
#
#                 timestamp
# 0 2021-02-10 10:45:32.889
# 1 2021-02-10 10:45:32.889
# 2 2021-02-10 10:45:32.889
# 3 2021-02-10 10:45:32.889
# 4 2021-02-10 10:45:32.889
# 5 2021-02-10 10:45:32.889
# 6 2021-02-10 10:45:32.889
# 7 2021-02-10 10:45:32.889
# 8 2021-02-10 10:45:32.889
# 9 2021-02-10 10:45:32.889

# %%
query.stop()

# %% [markdown]
# ## 2.6 Prepare the columns for model prediction

# %%
# By default day of week function, sunday is the first day of the week
# By using this udf, I will change to sunday is last day and monday is the first day of the week
getDayOfWeek = udf(lambda x: getWeek(x), IntegerType())
spark.udf.register("getDayOfWeek", getDayOfWeek)

def getWeek(week):
    if week == 1:
        week = 7
    else:
        week = week - 1
    return week

# Prepare the columns
counts_df_next = counts_df.withColumn("next_date", F.date_add(F.col("date_time").cast(DateType()),1))\
                          .withColumn("next_Mdate",F.dayofmonth(F.col("next_date")))\
                          .withColumn("next_day_week", F.weekofyear(F.col("next_date")))\
                          .withColumn("next_day_of_week", getDayOfWeek(F.dayofweek(F.col("next_date")).cast(IntegerType())))\
                          .withColumnRenamed("Hourly_Counts","prev_count")

# %%
# Print schema to test if the column is adding successful
counts_df_next.printSchema()
# Out:
# root
#  |-- ID: integer (nullable = true)
#  |-- Date_Time: timestamp (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Month: string (nullable = true)
#  |-- Mdate: integer (nullable = true)
#  |-- Day: string (nullable = true)
#  |-- Time: integer (nullable = true)
#  |-- Sensor_ID: integer (nullable = true)
#  |-- Sensor_Name: string (nullable = true)
#  |-- prev_count: integer (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- next_date: date (nullable = true)
#  |-- next_Mdate: integer (nullable = true)
#  |-- next_day_week: integer (nullable = true)
#  |-- next_day_of_week: integer (nullable = true)

# %%
# Query to test if the column is adding successful
query = counts_df_next\
    .writeStream\
    .outputMode("append")\
    .format("memory")\
    .queryName("counts_df")\
    .trigger(processingTime="2 seconds")\
    .start()

# %%
counts_df_next_query = spark.sql("select * from counts_df").toPandas()

# %%
counts_df_next_query.head(10)
# Out:
#         ID           Date_Time  Year     Month  Mdate        Day  Time  \
# 0  3448759 2020-12-09 23:00:00  2020  December      9  Wednesday    23
# 1  3447227 2020-12-09 00:00:00  2020  December      9  Wednesday     0
# 2  3447228 2020-12-09 00:00:00  2020  December      9  Wednesday     0
# 3  3447229 2020-12-09 00:00:00  2020  December      9  Wednesday     0
# 4  3447230 2020-12-09 00:00:00  2020  December      9  Wednesday     0
# 5  3447231 2020-12-09 00:00:00  2020  December      9  Wednesday     0
# 6  3447232 2020-12-09 00:00:00  2020  December      9  Wednesday     0
# 7  3447234 2020-12-09 00:00:00  2020  December      9  Wednesday     0
# 8  3447235 2020-12-09 00:00:00  2020  December      9  Wednesday     0
# 9  3447236 2020-12-09 00:00:00  2020  December      9  Wednesday     0
#
#    Sensor_ID                 Sensor_Name  prev_count               timestamp  \
# 0         35                   Southbank         294 2021-02-10 10:45:42.967
# 1          4            Town Hall (West)          84 2021-02-10 10:45:42.967
# 2         17       Collins Place (South)          17 2021-02-10 10:45:42.967
# 3         18       Collins Place (North)          11 2021-02-10 10:45:42.967
# 4         53          Collins St (North)          21 2021-02-10 10:45:42.967
# 5          2  Bourke Street Mall (South)          15 2021-02-10 10:45:42.967
# 6          1  Bourke Street Mall (North)          49 2021-02-10 10:45:42.967
# 7          9      Southern Cross Station          10 2021-02-10 10:45:42.967
# 8         10              Victoria Point          15 2021-02-10 10:45:42.967
# 9         12                    New Quay          12 2021-02-10 10:45:42.967
#
#     next_date  next_Mdate  next_day_week  next_day_of_week
# 0  2020-12-10          10             50                 4
# 1  2020-12-10          10             50                 4
# 2  2020-12-10          10             50                 4
# 3  2020-12-10          10             50                 4
# 4  2020-12-10          10             50                 4
# 5  2020-12-10          10             50                 4
# 6  2020-12-10          10             50                 4
# 7  2020-12-10          10             50                 4
# 8  2020-12-10          10             50                 4
# 9  2020-12-10          10             50                 4

# %%
query.stop()

# %% [markdown]
# ## 2.7 Predict the next day’s pedestrian count

# %%
#Loading the Pipeline Model From the filesystem
from pyspark.ml import PipelineModel
pipelineModel = PipelineModel.load('count_estimation_pipeline_model')
print(pipelineModel.stages[-1]._java_obj.paramMap())
# Out:
# {
# 	GBTRegressor_f98f56e12d10-labelCol: Hourly_Counts,
# 	GBTRegressor_f98f56e12d10-maxBins: 100,
# 	GBTRegressor_f98f56e12d10-maxDepth: 10
# }

# %%
# Use the provided model to predict between 9am-11:59pm
test_data = counts_df_next.filter((F.col('Time') >= 9) & (F.col('Time') <= 23))
prediction = pipelineModel.transform(test_data)

# %%
# Print schema to test if the prediction is successful
query = prediction\
    .writeStream\
    .outputMode("append")\
    .format("memory")\
    .queryName("prediction")\
    .trigger(processingTime="2 seconds")\
    .start()

# %%
prediction_show = spark.sql("select * from prediction").toPandas()

# %%
prediction_show.head(10)
# Out:
#         ID           Date_Time  Year     Month  Mdate       Day  Time  \
# 0  3452979 2020-12-12 17:00:00  2020  December     12  Saturday    17
# 1  3452459 2020-12-12 09:00:00  2020  December     12  Saturday     9
# 2  3452460 2020-12-12 09:00:00  2020  December     12  Saturday     9
# 3  3452461 2020-12-12 09:00:00  2020  December     12  Saturday     9
# 4  3452462 2020-12-12 09:00:00  2020  December     12  Saturday     9
# 5  3452463 2020-12-12 09:00:00  2020  December     12  Saturday     9
# 6  3452464 2020-12-12 09:00:00  2020  December     12  Saturday     9
# 7  3452465 2020-12-12 09:00:00  2020  December     12  Saturday     9
# 8  3452466 2020-12-12 09:00:00  2020  December     12  Saturday     9
# 9  3452467 2020-12-12 09:00:00  2020  December     12  Saturday     9
#
#    Sensor_ID                 Sensor_Name  prev_count               timestamp  \
# 0         12                    New Quay         382 2021-02-10 10:45:58.089
# 1          4            Town Hall (West)         761 2021-02-10 10:45:58.089
# 2         17       Collins Place (South)         118 2021-02-10 10:45:58.089
# 3         18       Collins Place (North)          53 2021-02-10 10:45:58.089
# 4         53          Collins St (North)         364 2021-02-10 10:45:58.089
# 5          2  Bourke Street Mall (South)         524 2021-02-10 10:45:58.089
# 6          1  Bourke Street Mall (North)         673 2021-02-10 10:45:58.089
# 7          9      Southern Cross Station          48 2021-02-10 10:45:58.089
# 8         10              Victoria Point          60 2021-02-10 10:45:58.089
# 9         12                    New Quay         195 2021-02-10 10:45:58.089
#
#     next_date  next_Mdate  next_day_week  next_day_of_week  \
# 0  2020-12-13          13             50                 7
# 1  2020-12-13          13             50                 7
# 2  2020-12-13          13             50                 7
# 3  2020-12-13          13             50                 7
# 4  2020-12-13          13             50                 7
# 5  2020-12-13          13             50                 7
# 6  2020-12-13          13             50                 7
# 7  2020-12-13          13             50                 7
# 8  2020-12-13          13             50                 7
# 9  2020-12-13          13             50                 7
#
#                                features  prediction
# 0  [17.0, 12.0, 382.0, 13.0, 50.0, 7.0]  505.330188
# 1    [9.0, 4.0, 761.0, 13.0, 50.0, 7.0]  634.486625
# 2   [9.0, 17.0, 118.0, 13.0, 50.0, 7.0]  127.054757
# 3    [9.0, 18.0, 53.0, 13.0, 50.0, 7.0]  126.313274
# 4   [9.0, 53.0, 364.0, 13.0, 50.0, 7.0]  377.545406
# 5    [9.0, 2.0, 524.0, 13.0, 50.0, 7.0]  444.175719
# 6    [9.0, 1.0, 673.0, 13.0, 50.0, 7.0]  548.925167
# 7     [9.0, 9.0, 48.0, 13.0, 50.0, 7.0]   70.964373
# 8    [9.0, 10.0, 60.0, 13.0, 50.0, 7.0]   67.719894
# 9   [9.0, 12.0, 195.0, 13.0, 50.0, 7.0]  268.702729

# %%
query.stop()

# %%
# Write to the parquet
prediciton_write_parquet = counts_df_read.writeStream\
.format("parquet")\
.outputMode("append")\
.option("path", "prediction.parquet")\
.option("checkpointLocation","parquet/prediction/checkpoint")\
.start()

# %%
prediciton_write_parquet.stop()

# %%
# Check if the write process is successful
prediction_write_parquet = spark.read.parquet("prediction.parquet")
prediction_write_parquet.printSchema()
# Out:
# root
#  |-- value: string (nullable = true)
#  |-- timestamp: string (nullable = true)

# %% [markdown]
# ## 2.8 Process the data analytics

# %% [markdown]
# ## 2.8 a

# %% [markdown]
# <a class="anchor" id="lab-task-1"></a>
# <div style="background:rgba(0,109,174,0.2);padding:10px;border-radius:4px"><strong style="color:#FF5555">DESCRIPTION</strong>
# <br>In this question, to get the number of hours that the predicted pedestrian counts exceed 2000 on each day in December, first is to filter the prediction, then I use the window function to make it transfer one day data in each time according to the timestamp.
# </div>

# %%
# Get the number of hours that the predicted pedestrian counts exceed 2000 on each day in December
prediction_processed = prediction\
    .filter(F.col("prediction") >= 2000)\
    .groupBy(F.window(prediction.timestamp, "4.9 seconds")\
             ,F.to_date("Date_Time").alias("Date"),"Sensor_ID")\
    .count()\
    .orderBy("Date","Sensor_ID")

# %%
# Use the query to check if the task is finished successful
query = prediction_processed\
    .writeStream\
    .outputMode("complete")\
    .format("memory")\
    .queryName("prediction_processed")\
    .trigger(processingTime="2 seconds")\
    .start()

# %%
prediction_processed_show = spark.sql("select * from prediction_processed")

# %%
prediction_processed_show.head(10000)
# Out:
# [Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000), end=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000)), Date=datetime.date(2020, 12, 1), Sensor_ID=1, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000), end=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000)), Date=datetime.date(2020, 12, 1), Sensor_ID=2, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000), end=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000)), Date=datetime.date(2020, 12, 1), Sensor_ID=4, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000), end=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000)), Date=datetime.date(2020, 12, 1), Sensor_ID=5, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000), end=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000)), Date=datetime.date(2020, 12, 1), Sensor_ID=6, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000), end=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000)), Date=datetime.date(2020, 12, 1), Sensor_ID=41, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000), end=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000)), Date=datetime.date(2020, 12, 1), Sensor_ID=58, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000), end=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000)), Date=datetime.date(2020, 12, 1), Sensor_ID=59, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000), end=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000)), Date=datetime.date(2020, 12, 1), Sensor_ID=63, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000), end=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000)), Date=datetime.date(2020, 12, 1), Sensor_ID=65, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000), end=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000)), Date=datetime.date(2020, 12, 1), Sensor_ID=67, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000), end=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000)), Date=datetime.date(2020, 12, 1), Sensor_ID=69, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000), end=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000)), Date=datetime.date(2020, 12, 2), Sensor_ID=1, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000), end=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000)), Date=datetime.date(2020, 12, 2), Sensor_ID=2, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000), end=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000)), Date=datetime.date(2020, 12, 2), Sensor_ID=4, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000), end=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000)), Date=datetime.date(2020, 12, 2), Sensor_ID=22, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000), end=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000)), Date=datetime.date(2020, 12, 2), Sensor_ID=24, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000), end=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000)), Date=datetime.date(2020, 12, 2), Sensor_ID=41, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000), end=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000)), Date=datetime.date(2020, 12, 2), Sensor_ID=58, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000), end=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000)), Date=datetime.date(2020, 12, 2), Sensor_ID=59, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000), end=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000)), Date=datetime.date(2020, 12, 2), Sensor_ID=63, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000), end=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000)), Date=datetime.date(2020, 12, 2), Sensor_ID=65, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000), end=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000)), Date=datetime.date(2020, 12, 2), Sensor_ID=67, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 40, 200000), end=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000)), Date=datetime.date(2020, 12, 2), Sensor_ID=68, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000), end=datetime.datetime(2021, 2, 10, 21, 47, 50)), Date=datetime.date(2020, 12, 3), Sensor_ID=1, count=8),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000), end=datetime.datetime(2021, 2, 10, 21, 47, 50)), Date=datetime.date(2020, 12, 3), Sensor_ID=2, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000), end=datetime.datetime(2021, 2, 10, 21, 47, 50)), Date=datetime.date(2020, 12, 3), Sensor_ID=4, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000), end=datetime.datetime(2021, 2, 10, 21, 47, 50)), Date=datetime.date(2020, 12, 3), Sensor_ID=22, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000), end=datetime.datetime(2021, 2, 10, 21, 47, 50)), Date=datetime.date(2020, 12, 3), Sensor_ID=35, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000), end=datetime.datetime(2021, 2, 10, 21, 47, 50)), Date=datetime.date(2020, 12, 3), Sensor_ID=41, count=10),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000), end=datetime.datetime(2021, 2, 10, 21, 47, 50)), Date=datetime.date(2020, 12, 3), Sensor_ID=59, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000), end=datetime.datetime(2021, 2, 10, 21, 47, 50)), Date=datetime.date(2020, 12, 3), Sensor_ID=63, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000), end=datetime.datetime(2021, 2, 10, 21, 47, 50)), Date=datetime.date(2020, 12, 3), Sensor_ID=65, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000), end=datetime.datetime(2021, 2, 10, 21, 47, 50)), Date=datetime.date(2020, 12, 3), Sensor_ID=67, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000), end=datetime.datetime(2021, 2, 10, 21, 47, 50)), Date=datetime.date(2020, 12, 3), Sensor_ID=68, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 45, 100000), end=datetime.datetime(2021, 2, 10, 21, 47, 50)), Date=datetime.date(2020, 12, 3), Sensor_ID=69, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 50), end=datetime.datetime(2021, 2, 10, 21, 47, 54, 900000)), Date=datetime.date(2020, 12, 4), Sensor_ID=1, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 50), end=datetime.datetime(2021, 2, 10, 21, 47, 54, 900000)), Date=datetime.date(2020, 12, 4), Sensor_ID=2, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 50), end=datetime.datetime(2021, 2, 10, 21, 47, 54, 900000)), Date=datetime.date(2020, 12, 4), Sensor_ID=4, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 50), end=datetime.datetime(2021, 2, 10, 21, 47, 54, 900000)), Date=datetime.date(2020, 12, 4), Sensor_ID=5, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 50), end=datetime.datetime(2021, 2, 10, 21, 47, 54, 900000)), Date=datetime.date(2020, 12, 4), Sensor_ID=35, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 50), end=datetime.datetime(2021, 2, 10, 21, 47, 54, 900000)), Date=datetime.date(2020, 12, 4), Sensor_ID=41, count=11),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 54, 900000), end=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000)), Date=datetime.date(2020, 12, 5), Sensor_ID=1, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 54, 900000), end=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000)), Date=datetime.date(2020, 12, 5), Sensor_ID=2, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 54, 900000), end=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000)), Date=datetime.date(2020, 12, 5), Sensor_ID=4, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 54, 900000), end=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000)), Date=datetime.date(2020, 12, 5), Sensor_ID=22, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 54, 900000), end=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000)), Date=datetime.date(2020, 12, 5), Sensor_ID=35, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 54, 900000), end=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000)), Date=datetime.date(2020, 12, 5), Sensor_ID=41, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 54, 900000), end=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000)), Date=datetime.date(2020, 12, 5), Sensor_ID=47, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=1, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=2, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=4, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=5, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=6, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=22, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=24, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=35, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=41, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=55, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=57, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=58, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=59, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=61, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=62, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=63, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=65, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=66, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=67, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=68, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 59, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000)), Date=datetime.date(2020, 12, 6), Sensor_ID=69, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000)), Date=datetime.date(2020, 12, 7), Sensor_ID=1, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000)), Date=datetime.date(2020, 12, 7), Sensor_ID=2, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000)), Date=datetime.date(2020, 12, 7), Sensor_ID=4, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000)), Date=datetime.date(2020, 12, 7), Sensor_ID=6, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000)), Date=datetime.date(2020, 12, 7), Sensor_ID=24, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000)), Date=datetime.date(2020, 12, 7), Sensor_ID=41, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000)), Date=datetime.date(2020, 12, 7), Sensor_ID=58, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000)), Date=datetime.date(2020, 12, 7), Sensor_ID=59, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000)), Date=datetime.date(2020, 12, 7), Sensor_ID=63, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000)), Date=datetime.date(2020, 12, 7), Sensor_ID=65, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000)), Date=datetime.date(2020, 12, 7), Sensor_ID=67, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000)), Date=datetime.date(2020, 12, 7), Sensor_ID=68, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 4, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000)), Date=datetime.date(2020, 12, 7), Sensor_ID=69, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000), end=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000)), Date=datetime.date(2020, 12, 8), Sensor_ID=1, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000), end=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000)), Date=datetime.date(2020, 12, 8), Sensor_ID=2, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000), end=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000)), Date=datetime.date(2020, 12, 8), Sensor_ID=4, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000), end=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000)), Date=datetime.date(2020, 12, 8), Sensor_ID=22, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000), end=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000)), Date=datetime.date(2020, 12, 8), Sensor_ID=24, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000), end=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000)), Date=datetime.date(2020, 12, 8), Sensor_ID=41, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000), end=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000)), Date=datetime.date(2020, 12, 8), Sensor_ID=59, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000), end=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000)), Date=datetime.date(2020, 12, 8), Sensor_ID=61, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000), end=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000)), Date=datetime.date(2020, 12, 8), Sensor_ID=65, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 9, 600000), end=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000)), Date=datetime.date(2020, 12, 8), Sensor_ID=69, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000), end=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000)), Date=datetime.date(2020, 12, 9), Sensor_ID=1, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000), end=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000)), Date=datetime.date(2020, 12, 9), Sensor_ID=2, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000), end=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000)), Date=datetime.date(2020, 12, 9), Sensor_ID=4, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000), end=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000)), Date=datetime.date(2020, 12, 9), Sensor_ID=5, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000), end=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000)), Date=datetime.date(2020, 12, 9), Sensor_ID=6, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000), end=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000)), Date=datetime.date(2020, 12, 9), Sensor_ID=22, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000), end=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000)), Date=datetime.date(2020, 12, 9), Sensor_ID=24, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000), end=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000)), Date=datetime.date(2020, 12, 9), Sensor_ID=41, count=8),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000), end=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000)), Date=datetime.date(2020, 12, 9), Sensor_ID=59, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000), end=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000)), Date=datetime.date(2020, 12, 9), Sensor_ID=61, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 14, 500000), end=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000)), Date=datetime.date(2020, 12, 9), Sensor_ID=69, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000), end=datetime.datetime(2021, 2, 10, 21, 48, 24, 300000)), Date=datetime.date(2020, 12, 10), Sensor_ID=1, count=8),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000), end=datetime.datetime(2021, 2, 10, 21, 48, 24, 300000)), Date=datetime.date(2020, 12, 10), Sensor_ID=2, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000), end=datetime.datetime(2021, 2, 10, 21, 48, 24, 300000)), Date=datetime.date(2020, 12, 10), Sensor_ID=4, count=8),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000), end=datetime.datetime(2021, 2, 10, 21, 48, 24, 300000)), Date=datetime.date(2020, 12, 10), Sensor_ID=5, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000), end=datetime.datetime(2021, 2, 10, 21, 48, 24, 300000)), Date=datetime.date(2020, 12, 10), Sensor_ID=6, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000), end=datetime.datetime(2021, 2, 10, 21, 48, 24, 300000)), Date=datetime.date(2020, 12, 10), Sensor_ID=22, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000), end=datetime.datetime(2021, 2, 10, 21, 48, 24, 300000)), Date=datetime.date(2020, 12, 10), Sensor_ID=35, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000), end=datetime.datetime(2021, 2, 10, 21, 48, 24, 300000)), Date=datetime.date(2020, 12, 10), Sensor_ID=41, count=11),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000), end=datetime.datetime(2021, 2, 10, 21, 48, 24, 300000)), Date=datetime.date(2020, 12, 10), Sensor_ID=59, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 19, 400000), end=datetime.datetime(2021, 2, 10, 21, 48, 24, 300000)), Date=datetime.date(2020, 12, 10), Sensor_ID=61, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 29, 200000), end=datetime.datetime(2021, 2, 10, 21, 48, 34, 100000)), Date=datetime.date(2020, 12, 11), Sensor_ID=1, count=10),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 29, 200000), end=datetime.datetime(2021, 2, 10, 21, 48, 34, 100000)), Date=datetime.date(2020, 12, 11), Sensor_ID=2, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 29, 200000), end=datetime.datetime(2021, 2, 10, 21, 48, 34, 100000)), Date=datetime.date(2020, 12, 11), Sensor_ID=4, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 29, 200000), end=datetime.datetime(2021, 2, 10, 21, 48, 34, 100000)), Date=datetime.date(2020, 12, 11), Sensor_ID=5, count=9),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 29, 200000), end=datetime.datetime(2021, 2, 10, 21, 48, 34, 100000)), Date=datetime.date(2020, 12, 11), Sensor_ID=22, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 29, 200000), end=datetime.datetime(2021, 2, 10, 21, 48, 34, 100000)), Date=datetime.date(2020, 12, 11), Sensor_ID=35, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 29, 200000), end=datetime.datetime(2021, 2, 10, 21, 48, 34, 100000)), Date=datetime.date(2020, 12, 11), Sensor_ID=41, count=12),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 29, 200000), end=datetime.datetime(2021, 2, 10, 21, 48, 34, 100000)), Date=datetime.date(2020, 12, 11), Sensor_ID=47, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 34, 100000), end=datetime.datetime(2021, 2, 10, 21, 48, 39)), Date=datetime.date(2020, 12, 12), Sensor_ID=1, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 34, 100000), end=datetime.datetime(2021, 2, 10, 21, 48, 39)), Date=datetime.date(2020, 12, 12), Sensor_ID=2, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 34, 100000), end=datetime.datetime(2021, 2, 10, 21, 48, 39)), Date=datetime.date(2020, 12, 12), Sensor_ID=4, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 34, 100000), end=datetime.datetime(2021, 2, 10, 21, 48, 39)), Date=datetime.date(2020, 12, 12), Sensor_ID=5, count=8),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 34, 100000), end=datetime.datetime(2021, 2, 10, 21, 48, 39)), Date=datetime.date(2020, 12, 12), Sensor_ID=22, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 34, 100000), end=datetime.datetime(2021, 2, 10, 21, 48, 39)), Date=datetime.date(2020, 12, 12), Sensor_ID=35, count=9),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 34, 100000), end=datetime.datetime(2021, 2, 10, 21, 48, 39)), Date=datetime.date(2020, 12, 12), Sensor_ID=41, count=12),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 34, 100000), end=datetime.datetime(2021, 2, 10, 21, 48, 39)), Date=datetime.date(2020, 12, 12), Sensor_ID=47, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=1, count=8),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=2, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=4, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=5, count=9),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=6, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=22, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=24, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=35, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=41, count=8),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=47, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=53, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=57, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=58, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=59, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=61, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=62, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=63, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=65, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=66, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=67, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=68, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 39), end=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000)), Date=datetime.date(2020, 12, 13), Sensor_ID=69, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000), end=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000)), Date=datetime.date(2020, 12, 14), Sensor_ID=1, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000), end=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000)), Date=datetime.date(2020, 12, 14), Sensor_ID=2, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000), end=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000)), Date=datetime.date(2020, 12, 14), Sensor_ID=4, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000), end=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000)), Date=datetime.date(2020, 12, 14), Sensor_ID=22, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000), end=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000)), Date=datetime.date(2020, 12, 14), Sensor_ID=24, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000), end=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000)), Date=datetime.date(2020, 12, 14), Sensor_ID=41, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000), end=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000)), Date=datetime.date(2020, 12, 14), Sensor_ID=59, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000), end=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000)), Date=datetime.date(2020, 12, 14), Sensor_ID=63, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000), end=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000)), Date=datetime.date(2020, 12, 14), Sensor_ID=65, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 43, 900000), end=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000)), Date=datetime.date(2020, 12, 14), Sensor_ID=67, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000)), Date=datetime.date(2020, 12, 15), Sensor_ID=1, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000)), Date=datetime.date(2020, 12, 15), Sensor_ID=2, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000)), Date=datetime.date(2020, 12, 15), Sensor_ID=4, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000)), Date=datetime.date(2020, 12, 15), Sensor_ID=5, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000)), Date=datetime.date(2020, 12, 15), Sensor_ID=6, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000)), Date=datetime.date(2020, 12, 15), Sensor_ID=22, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000)), Date=datetime.date(2020, 12, 15), Sensor_ID=24, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000)), Date=datetime.date(2020, 12, 15), Sensor_ID=41, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000)), Date=datetime.date(2020, 12, 15), Sensor_ID=63, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000)), Date=datetime.date(2020, 12, 15), Sensor_ID=65, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000)), Date=datetime.date(2020, 12, 15), Sensor_ID=67, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 48, 800000), end=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000)), Date=datetime.date(2020, 12, 15), Sensor_ID=69, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000)), Date=datetime.date(2020, 12, 16), Sensor_ID=1, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000)), Date=datetime.date(2020, 12, 16), Sensor_ID=2, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000)), Date=datetime.date(2020, 12, 16), Sensor_ID=4, count=8),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000)), Date=datetime.date(2020, 12, 16), Sensor_ID=5, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000)), Date=datetime.date(2020, 12, 16), Sensor_ID=6, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000)), Date=datetime.date(2020, 12, 16), Sensor_ID=22, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000)), Date=datetime.date(2020, 12, 16), Sensor_ID=24, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000)), Date=datetime.date(2020, 12, 16), Sensor_ID=41, count=10),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000)), Date=datetime.date(2020, 12, 16), Sensor_ID=68, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 53, 700000), end=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000)), Date=datetime.date(2020, 12, 16), Sensor_ID=69, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000), end=datetime.datetime(2021, 2, 10, 21, 49, 3, 500000)), Date=datetime.date(2020, 12, 17), Sensor_ID=1, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000), end=datetime.datetime(2021, 2, 10, 21, 49, 3, 500000)), Date=datetime.date(2020, 12, 17), Sensor_ID=2, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000), end=datetime.datetime(2021, 2, 10, 21, 49, 3, 500000)), Date=datetime.date(2020, 12, 17), Sensor_ID=4, count=11),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000), end=datetime.datetime(2021, 2, 10, 21, 49, 3, 500000)), Date=datetime.date(2020, 12, 17), Sensor_ID=5, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000), end=datetime.datetime(2021, 2, 10, 21, 49, 3, 500000)), Date=datetime.date(2020, 12, 17), Sensor_ID=22, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000), end=datetime.datetime(2021, 2, 10, 21, 49, 3, 500000)), Date=datetime.date(2020, 12, 17), Sensor_ID=35, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000), end=datetime.datetime(2021, 2, 10, 21, 49, 3, 500000)), Date=datetime.date(2020, 12, 17), Sensor_ID=41, count=10),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000), end=datetime.datetime(2021, 2, 10, 21, 49, 3, 500000)), Date=datetime.date(2020, 12, 17), Sensor_ID=59, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000), end=datetime.datetime(2021, 2, 10, 21, 49, 3, 500000)), Date=datetime.date(2020, 12, 17), Sensor_ID=61, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 48, 58, 600000), end=datetime.datetime(2021, 2, 10, 21, 49, 3, 500000)), Date=datetime.date(2020, 12, 17), Sensor_ID=68, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 3, 500000), end=datetime.datetime(2021, 2, 10, 21, 49, 8, 400000)), Date=datetime.date(2020, 12, 18), Sensor_ID=1, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 3, 500000), end=datetime.datetime(2021, 2, 10, 21, 49, 8, 400000)), Date=datetime.date(2020, 12, 18), Sensor_ID=2, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 3, 500000), end=datetime.datetime(2021, 2, 10, 21, 49, 8, 400000)), Date=datetime.date(2020, 12, 18), Sensor_ID=4, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 3, 500000), end=datetime.datetime(2021, 2, 10, 21, 49, 8, 400000)), Date=datetime.date(2020, 12, 18), Sensor_ID=5, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 3, 500000), end=datetime.datetime(2021, 2, 10, 21, 49, 8, 400000)), Date=datetime.date(2020, 12, 18), Sensor_ID=22, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 3, 500000), end=datetime.datetime(2021, 2, 10, 21, 49, 8, 400000)), Date=datetime.date(2020, 12, 18), Sensor_ID=35, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 3, 500000), end=datetime.datetime(2021, 2, 10, 21, 49, 8, 400000)), Date=datetime.date(2020, 12, 18), Sensor_ID=41, count=12),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 3, 500000), end=datetime.datetime(2021, 2, 10, 21, 49, 8, 400000)), Date=datetime.date(2020, 12, 18), Sensor_ID=47, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 8, 400000), end=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000)), Date=datetime.date(2020, 12, 19), Sensor_ID=1, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 8, 400000), end=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000)), Date=datetime.date(2020, 12, 19), Sensor_ID=2, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 8, 400000), end=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000)), Date=datetime.date(2020, 12, 19), Sensor_ID=4, count=8),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 8, 400000), end=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000)), Date=datetime.date(2020, 12, 19), Sensor_ID=5, count=9),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 8, 400000), end=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000)), Date=datetime.date(2020, 12, 19), Sensor_ID=22, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 8, 400000), end=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000)), Date=datetime.date(2020, 12, 19), Sensor_ID=28, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 8, 400000), end=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000)), Date=datetime.date(2020, 12, 19), Sensor_ID=35, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 8, 400000), end=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000)), Date=datetime.date(2020, 12, 19), Sensor_ID=41, count=12),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 8, 400000), end=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000)), Date=datetime.date(2020, 12, 19), Sensor_ID=45, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=1, count=8),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=2, count=8),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=4, count=11),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=5, count=11),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=6, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=22, count=8),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=24, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=28, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=35, count=9),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=41, count=12),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=47, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=53, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=55, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=57, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=58, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=59, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=61, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=62, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=63, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=65, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=66, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=67, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=68, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=69, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 13, 300000), end=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000)), Date=datetime.date(2020, 12, 20), Sensor_ID=73, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000), end=datetime.datetime(2021, 2, 10, 21, 49, 23, 100000)), Date=datetime.date(2020, 12, 21), Sensor_ID=1, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000), end=datetime.datetime(2021, 2, 10, 21, 49, 23, 100000)), Date=datetime.date(2020, 12, 21), Sensor_ID=2, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000), end=datetime.datetime(2021, 2, 10, 21, 49, 23, 100000)), Date=datetime.date(2020, 12, 21), Sensor_ID=4, count=8),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000), end=datetime.datetime(2021, 2, 10, 21, 49, 23, 100000)), Date=datetime.date(2020, 12, 21), Sensor_ID=5, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000), end=datetime.datetime(2021, 2, 10, 21, 49, 23, 100000)), Date=datetime.date(2020, 12, 21), Sensor_ID=6, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000), end=datetime.datetime(2021, 2, 10, 21, 49, 23, 100000)), Date=datetime.date(2020, 12, 21), Sensor_ID=22, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000), end=datetime.datetime(2021, 2, 10, 21, 49, 23, 100000)), Date=datetime.date(2020, 12, 21), Sensor_ID=41, count=9),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 18, 200000), end=datetime.datetime(2021, 2, 10, 21, 49, 23, 100000)), Date=datetime.date(2020, 12, 21), Sensor_ID=68, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 23, 100000), end=datetime.datetime(2021, 2, 10, 21, 49, 28)), Date=datetime.date(2020, 12, 22), Sensor_ID=1, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 46, 46, 300000), end=datetime.datetime(2021, 2, 10, 21, 46, 51, 200000)), Date=datetime.date(2020, 12, 22), Sensor_ID=1, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 23, 100000), end=datetime.datetime(2021, 2, 10, 21, 49, 28)), Date=datetime.date(2020, 12, 22), Sensor_ID=2, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 46, 46, 300000), end=datetime.datetime(2021, 2, 10, 21, 46, 51, 200000)), Date=datetime.date(2020, 12, 22), Sensor_ID=2, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 46, 46, 300000), end=datetime.datetime(2021, 2, 10, 21, 46, 51, 200000)), Date=datetime.date(2020, 12, 22), Sensor_ID=4, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 23, 100000), end=datetime.datetime(2021, 2, 10, 21, 49, 28)), Date=datetime.date(2020, 12, 22), Sensor_ID=4, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 23, 100000), end=datetime.datetime(2021, 2, 10, 21, 49, 28)), Date=datetime.date(2020, 12, 22), Sensor_ID=5, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 46, 46, 300000), end=datetime.datetime(2021, 2, 10, 21, 46, 51, 200000)), Date=datetime.date(2020, 12, 22), Sensor_ID=5, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 46, 46, 300000), end=datetime.datetime(2021, 2, 10, 21, 46, 51, 200000)), Date=datetime.date(2020, 12, 22), Sensor_ID=6, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 23, 100000), end=datetime.datetime(2021, 2, 10, 21, 49, 28)), Date=datetime.date(2020, 12, 22), Sensor_ID=6, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 49, 23, 100000), end=datetime.datetime(2021, 2, 10, 21, 49, 28)), Date=datetime.date(2020, 12, 22), Sensor_ID=24, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 46, 46, 300000), end=datetime.datetime(2021, 2, 10, 21, 46, 51, 200000)), Date=datetime.date(2020, 12, 22), Sensor_ID=24, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 46, 46, 300000), end=datetime.datetime(2021, 2, 10, 21, 46, 51, 200000)), Date=datetime.date(2020, 12, 22), Sensor_ID=41, count=7),
# ...
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 1), end=datetime.datetime(2021, 2, 10, 21, 47, 5, 900000)), Date=datetime.date(2020, 12, 25), Sensor_ID=6, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 1), end=datetime.datetime(2021, 2, 10, 21, 47, 5, 900000)), Date=datetime.date(2020, 12, 25), Sensor_ID=7, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 1), end=datetime.datetime(2021, 2, 10, 21, 47, 5, 900000)), Date=datetime.date(2020, 12, 25), Sensor_ID=35, count=8),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 1), end=datetime.datetime(2021, 2, 10, 21, 47, 5, 900000)), Date=datetime.date(2020, 12, 25), Sensor_ID=41, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 1), end=datetime.datetime(2021, 2, 10, 21, 47, 5, 900000)), Date=datetime.date(2020, 12, 25), Sensor_ID=65, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 5, 900000), end=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000)), Date=datetime.date(2020, 12, 26), Sensor_ID=1, count=9),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 5, 900000), end=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000)), Date=datetime.date(2020, 12, 26), Sensor_ID=2, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 5, 900000), end=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000)), Date=datetime.date(2020, 12, 26), Sensor_ID=4, count=8),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 5, 900000), end=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000)), Date=datetime.date(2020, 12, 26), Sensor_ID=5, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 5, 900000), end=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000)), Date=datetime.date(2020, 12, 26), Sensor_ID=22, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 5, 900000), end=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000)), Date=datetime.date(2020, 12, 26), Sensor_ID=35, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 5, 900000), end=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000)), Date=datetime.date(2020, 12, 26), Sensor_ID=41, count=10),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 5, 900000), end=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000)), Date=datetime.date(2020, 12, 26), Sensor_ID=45, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 5, 900000), end=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000)), Date=datetime.date(2020, 12, 26), Sensor_ID=47, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 5, 900000), end=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000)), Date=datetime.date(2020, 12, 26), Sensor_ID=66, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=1, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=2, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=4, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=5, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=6, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=22, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=35, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=41, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=47, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=57, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=58, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=59, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=61, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=62, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=63, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=65, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=66, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=67, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=68, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=69, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 10, 800000), end=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000)), Date=datetime.date(2020, 12, 27), Sensor_ID=73, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000), end=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000)), Date=datetime.date(2020, 12, 28), Sensor_ID=1, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000), end=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000)), Date=datetime.date(2020, 12, 28), Sensor_ID=2, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000), end=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000)), Date=datetime.date(2020, 12, 28), Sensor_ID=4, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000), end=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000)), Date=datetime.date(2020, 12, 28), Sensor_ID=5, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000), end=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000)), Date=datetime.date(2020, 12, 28), Sensor_ID=6, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000), end=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000)), Date=datetime.date(2020, 12, 28), Sensor_ID=22, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000), end=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000)), Date=datetime.date(2020, 12, 28), Sensor_ID=28, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000), end=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000)), Date=datetime.date(2020, 12, 28), Sensor_ID=35, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000), end=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000)), Date=datetime.date(2020, 12, 28), Sensor_ID=41, count=8),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000), end=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000)), Date=datetime.date(2020, 12, 28), Sensor_ID=58, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000), end=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000)), Date=datetime.date(2020, 12, 28), Sensor_ID=59, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000), end=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000)), Date=datetime.date(2020, 12, 28), Sensor_ID=67, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000), end=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000)), Date=datetime.date(2020, 12, 28), Sensor_ID=68, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 15, 700000), end=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000)), Date=datetime.date(2020, 12, 28), Sensor_ID=69, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000), end=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000)), Date=datetime.date(2020, 12, 29), Sensor_ID=1, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000), end=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000)), Date=datetime.date(2020, 12, 29), Sensor_ID=2, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000), end=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000)), Date=datetime.date(2020, 12, 29), Sensor_ID=4, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000), end=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000)), Date=datetime.date(2020, 12, 29), Sensor_ID=5, count=7),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000), end=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000)), Date=datetime.date(2020, 12, 29), Sensor_ID=6, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000), end=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000)), Date=datetime.date(2020, 12, 29), Sensor_ID=22, count=6),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000), end=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000)), Date=datetime.date(2020, 12, 29), Sensor_ID=35, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000), end=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000)), Date=datetime.date(2020, 12, 29), Sensor_ID=41, count=8),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000), end=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000)), Date=datetime.date(2020, 12, 29), Sensor_ID=59, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 20, 600000), end=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000)), Date=datetime.date(2020, 12, 29), Sensor_ID=68, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000), end=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000)), Date=datetime.date(2020, 12, 30), Sensor_ID=1, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000), end=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000)), Date=datetime.date(2020, 12, 30), Sensor_ID=2, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000), end=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000)), Date=datetime.date(2020, 12, 30), Sensor_ID=4, count=9),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000), end=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000)), Date=datetime.date(2020, 12, 30), Sensor_ID=5, count=8),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000), end=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000)), Date=datetime.date(2020, 12, 30), Sensor_ID=6, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000), end=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000)), Date=datetime.date(2020, 12, 30), Sensor_ID=11, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000), end=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000)), Date=datetime.date(2020, 12, 30), Sensor_ID=12, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000), end=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000)), Date=datetime.date(2020, 12, 30), Sensor_ID=22, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000), end=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000)), Date=datetime.date(2020, 12, 30), Sensor_ID=35, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000), end=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000)), Date=datetime.date(2020, 12, 30), Sensor_ID=41, count=8),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000), end=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000)), Date=datetime.date(2020, 12, 30), Sensor_ID=59, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000), end=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000)), Date=datetime.date(2020, 12, 30), Sensor_ID=68, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 25, 500000), end=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000)), Date=datetime.date(2020, 12, 30), Sensor_ID=69, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000), end=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000)), Date=datetime.date(2020, 12, 31), Sensor_ID=2, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000), end=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000)), Date=datetime.date(2020, 12, 31), Sensor_ID=4, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000), end=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000)), Date=datetime.date(2020, 12, 31), Sensor_ID=5, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000), end=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000)), Date=datetime.date(2020, 12, 31), Sensor_ID=35, count=4),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000), end=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000)), Date=datetime.date(2020, 12, 31), Sensor_ID=41, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000), end=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000)), Date=datetime.date(2020, 12, 31), Sensor_ID=57, count=10),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000), end=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000)), Date=datetime.date(2020, 12, 31), Sensor_ID=58, count=5),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000), end=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000)), Date=datetime.date(2020, 12, 31), Sensor_ID=59, count=3),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000), end=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000)), Date=datetime.date(2020, 12, 31), Sensor_ID=61, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000), end=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000)), Date=datetime.date(2020, 12, 31), Sensor_ID=63, count=1),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000), end=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000)), Date=datetime.date(2020, 12, 31), Sensor_ID=65, count=2),
#  Row(window=Row(start=datetime.datetime(2021, 2, 10, 21, 47, 30, 400000), end=datetime.datetime(2021, 2, 10, 21, 47, 35, 300000)), Date=datetime.date(2020, 12, 31), Sensor_ID=68, count=5)]

# %%
query.stop()

# %% [markdown]
# ## 2.8 b

# %% [markdown]
# <a class="anchor" id="lab-task-1"></a>
# <div style="background:rgba(0,109,174,0.2);padding:10px;border-radius:4px"><strong style="color:#FF5555">DESCRIPTION</strong>
# <br>This question asks if any sensor’s hourly count between 9am-11:59pm on the next day is predicted to exceed 2000, combine the result with sensor longitude and latitude information. First is to filter the prediction, then is to join the streaming data with the static sencor location information dataset.
# </div>

# %%
# Combine the sensors whcih has more than 2000 hourly count with sensor location information
prediction_join = prediction \
    .filter(F.col("prediction") >= 2000) \
    .join(df_sensor, prediction.Sensor_ID == df_sensor.sensor_id)\
    .select(prediction["*"],df_sensor["latitude"],df_sensor["longitude"])

# %%
# Test if the join is successful
query = prediction_join\
    .writeStream\
    .outputMode("append")\
    .format("memory")\
    .queryName("prediction_join")\
    .trigger(processingTime="2 seconds")\
    .start()

# %%
prediction_join_show = spark.sql("select * from prediction_join").toPandas()

# %%
prediction_join_show.head(10)
# Out:
#         ID           Date_Time  Year     Month  Mdate       Day  Time  \
# 0  3441825 2020-12-05 11:00:00  2020  December      5  Saturday    11
# 1  3441851 2020-12-05 12:00:00  2020  December      5  Saturday    12
# 2  3441855 2020-12-05 12:00:00  2020  December      5  Saturday    12
# 3  3441889 2020-12-05 12:00:00  2020  December      5  Saturday    12
# 4  3441915 2020-12-05 13:00:00  2020  December      5  Saturday    13
# 5  3441919 2020-12-05 13:00:00  2020  December      5  Saturday    13
# 6  3441920 2020-12-05 13:00:00  2020  December      5  Saturday    13
# 7  3441937 2020-12-05 13:00:00  2020  December      5  Saturday    13
# 8  3441953 2020-12-05 13:00:00  2020  December      5  Saturday    13
# 9  3441979 2020-12-05 14:00:00  2020  December      5  Saturday    14
#
#    Sensor_ID                      Sensor_Name  prev_count  \
# 0         41   Flinders La-Swanston St (West)        2292
# 1          4                 Town Hall (West)        2397
# 2          2       Bourke Street Mall (South)        1900
# 3         41   Flinders La-Swanston St (West)        2672
# 4          4                 Town Hall (West)        2597
# 5          2       Bourke Street Mall (South)        2247
# 6          1       Bourke Street Mall (North)        2728
# 7         22  Flinders St-Elizabeth St (East)        2063
# 8         41   Flinders La-Swanston St (West)        2908
# 9          4                 Town Hall (West)        2517
#
#                 timestamp   next_date  next_Mdate  next_day_week  \
# 0 2021-02-10 10:50:35.303  2020-12-06           6             49
# 1 2021-02-10 10:50:35.303  2020-12-06           6             49
# 2 2021-02-10 10:50:35.303  2020-12-06           6             49
# 3 2021-02-10 10:50:35.303  2020-12-06           6             49
# 4 2021-02-10 10:50:35.303  2020-12-06           6             49
# 5 2021-02-10 10:50:35.303  2020-12-06           6             49
# 6 2021-02-10 10:50:35.303  2020-12-06           6             49
# 7 2021-02-10 10:50:35.303  2020-12-06           6             49
# 8 2021-02-10 10:50:35.303  2020-12-06           6             49
# 9 2021-02-10 10:50:35.303  2020-12-06           6             49
#
#    next_day_of_week                              features   prediction  \
# 0                 7  [11.0, 41.0, 2292.0, 6.0, 49.0, 7.0]  2445.197393
# 1                 7   [12.0, 4.0, 2397.0, 6.0, 49.0, 7.0]  2126.286330
# 2                 7   [12.0, 2.0, 1900.0, 6.0, 49.0, 7.0]  2066.017341
# 3                 7  [12.0, 41.0, 2672.0, 6.0, 49.0, 7.0]  3172.878265
# 4                 7   [13.0, 4.0, 2597.0, 6.0, 49.0, 7.0]  2808.595969
# 5                 7   [13.0, 2.0, 2247.0, 6.0, 49.0, 7.0]  2350.521619
# 6                 7   [13.0, 1.0, 2728.0, 6.0, 49.0, 7.0]  2625.709001
# 7                 7  [13.0, 22.0, 2063.0, 6.0, 49.0, 7.0]  2035.271425
# 8                 7  [13.0, 41.0, 2908.0, 6.0, 49.0, 7.0]  3212.116862
# 9                 7   [14.0, 4.0, 2517.0, 6.0, 49.0, 7.0]  2878.110540
#
#     latitude   longitude
# 0 -37.816685  144.966904
# 1 -37.814880  144.966095
# 2 -37.813808  144.965164
# 3 -37.816685  144.966904
# 4 -37.814880  144.966095
# 5 -37.813808  144.965164
# 6 -37.813496  144.965149
# 7 -37.817863  144.965073
# 8 -37.816685  144.966904
# 9 -37.814880  144.966095

# %%
query.stop()

# %%
# Select the column information that will be used in task 3.
df_map = prediction_join\
               .withColumn("value", F.to_json(F.struct("Date_Time", "latitude", "longitude","Sensor_ID")))\
               .withColumn("key", F.col("Date_Time"))\
               .select("key","value")

# %%
query = df_map\
    .writeStream\
    .outputMode("append")\
    .format("memory")\
    .queryName("df_map")\
    .trigger(processingTime="2 seconds")\
    .start()

# %%
df_map_show = spark.sql("select * from df_map").toPandas()

# %%
df_map_show.head(10)
# Out:
#                   key                                              value
# 0 2020-12-07 12:00:00  {"Date_Time":"2020-12-07T12:00:00.000Z","latit...
# 1 2020-12-07 12:00:00  {"Date_Time":"2020-12-07T12:00:00.000Z","latit...
# 2 2020-12-07 12:00:00  {"Date_Time":"2020-12-07T12:00:00.000Z","latit...
# 3 2020-12-07 12:00:00  {"Date_Time":"2020-12-07T12:00:00.000Z","latit...
# 4 2020-12-07 12:00:00  {"Date_Time":"2020-12-07T12:00:00.000Z","latit...
# 5 2020-12-07 12:00:00  {"Date_Time":"2020-12-07T12:00:00.000Z","latit...
# 6 2020-12-07 12:00:00  {"Date_Time":"2020-12-07T12:00:00.000Z","latit...
# 7 2020-12-07 13:00:00  {"Date_Time":"2020-12-07T13:00:00.000Z","latit...
# 8 2020-12-07 13:00:00  {"Date_Time":"2020-12-07T13:00:00.000Z","latit...
# 9 2020-12-07 13:00:00  {"Date_Time":"2020-12-07T13:00:00.000Z","latit...

# %%
query.stop()

# %%
ds = df_map\
  .selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)")\
  .writeStream\
  .outputMode("append")\
  .format("kafka")\
  .option("kafka.bootstrap.servers", "127.0.0.1:9092")\
  .option("topic", "map")\
  .option("checkpointLocation","df_map/checkpoint")\
  .start()

# %%
ds.stop()
